# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
import scipy.stats as stats
from scipy.stats import zscore

from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
import xgboost as xgb

from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
glass = pd.read_csv('Glass project')
glass.head()
# Out:
#    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1
# 0  1.51761  13.89  3.60  1.36  72.73  0.48  7.83   0.0    0.00  1
# 1  1.51618  13.53  3.55  1.54  72.99  0.39  7.78   0.0    0.00  1
# 2  1.51766  13.21  3.69  1.29  72.61  0.57  8.22   0.0    0.00  1
# 3  1.51742  13.27  3.62  1.24  73.08  0.55  8.07   0.0    0.00  1
# 4  1.51596  12.79  3.61  1.62  72.97  0.64  8.07   0.0    0.26  1

# %%
glass.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   1.52101  213 non-null    float64
#  1   13.64    213 non-null    float64
#  2   4.49     213 non-null    float64
#  3   1.10     213 non-null    float64
#  4   71.78    213 non-null    float64
#  5   0.06     213 non-null    float64
#  6   8.75     213 non-null    float64
#  7   0.00     213 non-null    float64
#  8   0.00.1   213 non-null    float64
#  9   1        213 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
glass.shape
# Out:
# (213, 10)

# %%
glass.dtypes
# Out:
# 1.52101    float64
# 13.64      float64
# 4.49       float64
# 1.10       float64
# 71.78      float64
# 0.06       float64
# 8.75       float64
# 0.00       float64
# 0.00.1     float64
# 1            int64
# dtype: object

# %%
names = ['Id','RI','Na','Mg','Al','Si','K','Ca','Ba','Fe',]
glass.columns = names
glass.head()
# Out:
#         Id     RI    Na    Mg     Al    Si     K   Ca    Ba  Fe
# 0  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.00   1
# 1  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.00   1
# 2  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.00   1
# 3  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.00   1
# 4  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.0  0.26   1

# %%
glass.describe()
# Out:
#                Id          RI          Na          Mg          Al          Si  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000  213.000000
# mean     1.518353   13.406761    2.676056    1.446526   72.655023    0.499108
# std      0.003039    0.818371    1.440453    0.499882    0.774052    0.653035
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516520   12.900000    2.090000    1.190000   72.280000    0.130000
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.560000
# 75%      1.519150   13.830000    3.600000    1.630000   73.090000    0.610000
# max      1.533930   17.380000    3.980000    3.500000   75.410000    6.210000
#
#                 K          Ca          Ba          Fe
# count  213.000000  213.000000  213.000000  213.000000
# mean     8.957934    0.175869    0.057277    2.788732
# std      1.426435    0.498245    0.097589    2.105130
# ...

# %%
glass.isnull().sum()
# Out:
# Id    0
# RI    0
# Na    0
# Mg    0
# Al    0
# Si    0
# K     0
# Ca    0
# Ba    0
# Fe    0
# dtype: int64

# %%
glass.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Id      213 non-null    float64
#  1   RI      213 non-null    float64
#  2   Na      213 non-null    float64
#  3   Mg      213 non-null    float64
#  4   Al      213 non-null    float64
#  5   Si      213 non-null    float64
#  6   K       213 non-null    float64
#  7   Ca      213 non-null    float64
#  8   Ba      213 non-null    float64
#  9   Fe      213 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
glass.skew()
# Out:
# Id    1.639658
# RI    0.457318
# Na   -1.154323
# Mg    0.900017
# Al   -0.744546
# Si    6.549276
# K     2.040591
# Ca    3.406749
# Ba    1.747173
# Fe    1.108861
# dtype: float64

# %%
 plt.figure(figsize=(10,7))
sns.countplot(x ='Fe', data =glass)
plt.xlabel('Quality of glass')
plt.ylabel('Count of Rows in the dataset')
plt.show()

# %%
index=0
labels = glass['Fe']
features = glass.drop('Fe', axis=1)

for col in features.items():
    plt.figure(figsize=(10,5))
    sns.barplot(x=labels, y=col[index], data=glass, color="deeppink")
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(ncols=6, nrows=2, figsize=(15,10))
index = 0
ax = ax.flatten()
for col, value in glass.items():
    sns.boxplot(y=col, data=glass, ax=ax[index])
    index += 1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)
plt.show()

# %%
fig, ax = plt.subplots(ncols=6, nrows=2, figsize=(15,10))
index = 0
ax = ax.flatten()
for col, value in glass.items():
    sns.distplot(value, ax=ax[index], hist=False, color="g", kde_kws={"shade": True})
    index += 1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)
plt.show()

# %%
lower_triangle = np.tril(glass.corr())
plt.figure(figsize=(15,10))
sns.heatmap(glass.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', 
            annot_kws={'size':10}, cmap="Spectral", mask=lower_triangle)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
z=np.abs(zscore(glass))
threshold=3
np.where(z>3)

glass=glass[(z<3).all(axis=1)]
glass
# Out:
#           Id     RI    Na    Mg     Al    Si     K    Ca    Ba  Fe
# 0    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.00   1
# 1    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.00   1
# 2    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.00   1
# 3    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.00   1
# 4    1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00  0.26   1
# ..       ...    ...   ...   ...    ...   ...   ...   ...   ...  ..
# 207  1.51640  14.37  0.00  2.74  72.85  0.00  9.45  0.54  0.00   7
# 208  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.00   7
# 209  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.00   7
# 210  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.00   7
# 211  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.00   7
#
# [193 rows x 10 columns]

# %%
data_loss=(1599-1464)/1599*100 
# 1599 (number of rows in the original dataframe) and 1464 (number of rows after outlier removal)
data_loss
# Out:
# 8.442776735459661

# %%
X = glass.drop('Fe', axis=1)
Y = glass['Fe']

# %%
Y.value_counts()
# Out:
# 1    69
# 2    68
# 7    23
# 3    16
# 5     9
# 6     8
# Name: Fe, dtype: int64

# %%
oversample = SMOTE()
X, Y = oversample.fit_resample(X, Y)

# %%
Y.value_counts()
# Out:
# 1    69
# 2    69
# 3    69
# 5    69
# 6    69
# 7    69
# Name: Fe, dtype: int64

# %%
Y # Displaying just the label
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 409    7
# 410    7
# 411    7
# 412    7
# 413    7
# Name: Fe, Length: 414, dtype: int64

# %%
Y = Y.apply(lambda y_value:1 if y_value>=7 else 0)
Y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 409    1
# 410    1
# 411    1
# 412    1
# 413    1
# Name: Fe, Length: 414, dtype: int64

# %%
X
# Out:
#            Id         RI    Na        Mg         Al        Si         K  \
# 0    1.517610  13.890000  3.60  1.360000  72.730000  0.480000  7.830000
# 1    1.516180  13.530000  3.55  1.540000  72.990000  0.390000  7.780000
# 2    1.517660  13.210000  3.69  1.290000  72.610000  0.570000  8.220000
# 3    1.517420  13.270000  3.62  1.240000  73.080000  0.550000  8.070000
# 4    1.515960  12.790000  3.61  1.620000  72.970000  0.640000  8.070000
# ..        ...        ...   ...       ...        ...       ...       ...
# 409  1.516382  14.806530  0.00  2.368408  73.280000  0.000000  8.815061
# 410  1.516499  14.479549  0.00  1.927556  73.521117  0.000000  8.513776
# 411  1.516008  14.243482  0.00  2.758597  73.373037  0.040000  9.049663
# 412  1.516837  14.563507  0.00  1.980369  73.285017  0.000000  8.520185
# 413  1.515480  14.378440  0.00  2.672483  73.060990  0.033758  9.137735
#
#            Ca        Ba
# 0    0.000000  0.000000
# 1    0.000000  0.000000
# 2    0.000000  0.000000
# ...

# %%
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X # Displaying all the features after applying scaling technique to avoid bias output
# Out:
#            Id        RI        Na        Mg        Al        Si         K  \
# 0   -0.257332  0.454623  0.961928 -0.415526 -0.194638  0.485888 -1.209716
# 1   -0.941135 -0.005077  0.928613 -0.010931  0.308111  0.172814 -1.251843
# 2   -0.233423 -0.413699  1.021895 -0.572869 -0.426676  0.798962 -0.881127
# 3   -0.348187 -0.337082  0.975254 -0.685256  0.482140  0.729390 -1.007507
# 4   -1.046335 -0.950015  0.968591  0.168889  0.269438  1.042465 -1.007507
# ..        ...       ...       ...       ...       ...       ...       ...
# 409 -0.844424  1.624980 -1.436754  1.851125  0.868870 -1.183841 -0.379765
# 410 -0.788435  1.207444 -1.436754  0.860199  1.335105 -1.183841 -0.633610
# 411 -1.023497  0.905999 -1.436754  2.728171  1.048770 -1.044697 -0.182105
# 412 -0.627138  1.314653 -1.436754  0.978909  0.878570 -1.183841 -0.628210
# 413 -1.275824  1.078332 -1.436754  2.534610  0.445381 -1.066409 -0.107901
#
#            Ca        Ba
# 0   -0.410208 -0.529653
# 1   -0.410208 -0.529653
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=21)

# %%
def classify(model, X, Y):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=21)
    
    # Training the model
    model.fit(X_train, Y_train)
    
    # Predicting Y_test
    pred = model.predict(X_test)
    
    # Accuracy Score
    acc_score = (accuracy_score(Y_test, pred))*100
    print("Accuracy Score:", acc_score)
    
    # Classification Report
    class_report = classification_report(Y_test, pred)
    print("\nClassification Report:\n", class_report)
    
    # Cross Validation Score
    cv_score = (cross_val_score(model, X, Y, cv=5).mean())*100
    print("Cross Validation Score:", cv_score)
    
    # Result of accuracy minus cv scores
    result = acc_score - cv_score
    print("\nAccuracy Score - Cross Validation Score is", result)

# %%
model=LogisticRegression()
classify(model, X, Y)
# Out:
# Accuracy Score: 100.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        70
#            1       1.00      1.00      1.00        13
#
#     accuracy                           1.00        83
#    macro avg       1.00      1.00      1.00        83
# weighted avg       1.00      1.00      1.00        83
#
# Cross Validation Score: 99.7590361445783
#
# Accuracy Score - Cross Validation Score is 0.24096385542169685

# %%
model=SVC(C=1.0, kernel='rbf', gamma='auto', random_state=42)
classify(model, X, Y)
# Out:
# Accuracy Score: 98.79518072289156
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        70
#            1       1.00      0.92      0.96        13
#
#     accuracy                           0.99        83
#    macro avg       0.99      0.96      0.98        83
# weighted avg       0.99      0.99      0.99        83
#
# Cross Validation Score: 99.27710843373492
#
# Accuracy Score - Cross Validation Score is -0.4819277108433653

# %%
model=DecisionTreeClassifier(random_state=21, max_depth=15)
classify(model, X, Y)
# Out:
# Accuracy Score: 100.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        70
#            1       1.00      1.00      1.00        13
#
#     accuracy                           1.00        83
#    macro avg       1.00      1.00      1.00        83
# weighted avg       1.00      1.00      1.00        83
#
# Cross Validation Score: 99.51807228915662
#
# Accuracy Score - Cross Validation Score is 0.4819277108433795

# %%
model=RandomForestClassifier(max_depth=15, random_state=111)
classify(model, X, Y)
# Out:
# Accuracy Score: 100.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        70
#            1       1.00      1.00      1.00        13
#
#     accuracy                           1.00        83
#    macro avg       1.00      1.00      1.00        83
# weighted avg       1.00      1.00      1.00        83
#
# Cross Validation Score: 99.51807228915662
#
# Accuracy Score - Cross Validation Score is 0.4819277108433795

# %%
model=KNeighborsClassifier(n_neighbors=15)
classify(model, X, Y)
# Out:
# Accuracy Score: 98.79518072289156
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        70
#            1       1.00      0.92      0.96        13
#
#     accuracy                           0.99        83
#    macro avg       0.99      0.96      0.98        83
# weighted avg       0.99      0.99      0.99        83
#
# Cross Validation Score: 98.06053482221569
#
# Accuracy Score - Cross Validation Score is 0.7346459006758721

# %%
model=ExtraTreesClassifier()
classify(model, X, Y)
# Out:
# Accuracy Score: 100.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        70
#            1       1.00      1.00      1.00        13
#
#     accuracy                           1.00        83
#    macro avg       1.00      1.00      1.00        83
# weighted avg       1.00      1.00      1.00        83
#
# Cross Validation Score: 99.7590361445783
#
# Accuracy Score - Cross Validation Score is 0.24096385542169685

# %%
model=xgb.XGBClassifier(verbosity=0)
classify(model, X, Y)
# Out:
# Accuracy Score: 100.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        70
#            1       1.00      1.00      1.00        13
#
#     accuracy                           1.00        83
#    macro avg       1.00      1.00      1.00        83
# weighted avg       1.00      1.00      1.00        83
#
# Cross Validation Score: 99.51807228915662
#
# Accuracy Score - Cross Validation Score is 0.4819277108433795

# %%
# !pip install lightgbm

# %%
import lightgbm as lgb

# %%
model=lgb.LGBMClassifier()
classify(model, X, Y)
# Out:
# [LightGBM] [Info] Number of positive: 56, number of negative: 275
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000714 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 737
# [LightGBM] [Info] Number of data points in the train set: 331, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.169184 -> initscore=-1.591419
# [LightGBM] [Info] Start training from score -1.591419
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
Final_Model = SVC(decision_function_shape='ovo', gamma='scale', kernel='rbf', probability=True, random_state=21,
                 shrinking=True, verbose=True)
Classifier = Final_Model.fit(X_train, Y_train)
fmod_pred = Final_Model.predict(X_test)
fmod_acc = (accuracy_score(Y_test, fmod_pred))*100
print("Accuracy score for the Best Model is:", fmod_acc)
# Out:
# [LibSVM]Accuracy score for the Best Model is: 98.79518072289156

# %%
disp = metrics.plot_roc_curve(Final_Model, X_test, Y_test)
disp.figure_.suptitle("ROC Curve")
plt.show()

# %%
class_names = glass.columns
metrics.plot_confusion_matrix(Classifier, X_test, Y_test, cmap='mako')
plt.title('\t Confusion Matrix for Decision Tree Classifier \n')
plt.show()
